# %% [markdown]
# ## Baseline: Adam + OneCycle

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 2 \
                --opt adam
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.160112</td>
#       <td>2.477848</td>
#       <td>0.258000</td>
#       <td>0.720000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.959346</td>
#       <td>5.551616</td>
#       <td>0.166000</td>
#       <td>0.752000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.762096</td>
#       <td>1.816853</td>
#       <td>0.460000</td>
#       <td>0.878000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.567608</td>
#       <td>1.610225</td>
#       <td>0.518000</td>
#       <td>0.908000</td>
#       <td>00:14</td>
#     </tr>
# ...

# %% [markdown]
# ## Over9000 (RAdam + LARS + LookAHead) + flat_and_anneal

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 2 \
                --opt over9000 --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.217497</td>
#       <td>2.135265</td>
#       <td>0.294000</td>
#       <td>0.780000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.973137</td>
#       <td>4.340730</td>
#       <td>0.138000</td>
#       <td>0.732000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.772939</td>
#       <td>2.108456</td>
#       <td>0.276000</td>
#       <td>0.826000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.552774</td>
#       <td>1.593451</td>
#       <td>0.490000</td>
#       <td>0.926000</td>
#       <td>00:22</td>
#     </tr>
# ...

# %% [markdown]
# ## Ralamb (RAdam + LARS)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 2 \
                --opt ralamb --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.252903</td>
#       <td>2.546933</td>
#       <td>0.200000</td>
#       <td>0.686000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.024339</td>
#       <td>2.230221</td>
#       <td>0.282000</td>
#       <td>0.772000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.829086</td>
#       <td>1.894237</td>
#       <td>0.410000</td>
#       <td>0.824000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.651813</td>
#       <td>1.639337</td>
#       <td>0.462000</td>
#       <td>0.916000</td>
#       <td>00:20</td>
#     </tr>
# ...

# %% [markdown]
# ## Ranger (RAdam + LookAHead)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 2 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.168531</td>
#       <td>2.146417</td>
#       <td>0.280000</td>
#       <td>0.776000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.957279</td>
#       <td>2.183777</td>
#       <td>0.276000</td>
#       <td>0.762000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.791683</td>
#       <td>2.122745</td>
#       <td>0.360000</td>
#       <td>0.770000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.608359</td>
#       <td>1.760961</td>
#       <td>0.438000</td>
#       <td>0.884000</td>
#       <td>00:15</td>
#     </tr>
# ...

# %% [markdown]
# ## Novograd + bigger lr

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 3e-2 --gpu 2 \
                --opt novograd --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.096984</td>
#       <td>2.343435</td>
#       <td>0.234000</td>
#       <td>0.690000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.929333</td>
#       <td>2.036119</td>
#       <td>0.314000</td>
#       <td>0.826000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.780675</td>
#       <td>1.910979</td>
#       <td>0.390000</td>
#       <td>0.870000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.592823</td>
#       <td>1.527533</td>
#       <td>0.550000</td>
#       <td>0.942000</td>
#       <td>00:16</td>
#     </tr>
# ...

# %% [markdown]
# ## Radam

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 2 \
                --opt radam --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.234692</td>
#       <td>2.171374</td>
#       <td>0.266000</td>
#       <td>0.790000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.050453</td>
#       <td>2.487563</td>
#       <td>0.276000</td>
#       <td>0.794000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.870237</td>
#       <td>2.070423</td>
#       <td>0.276000</td>
#       <td>0.802000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.710685</td>
#       <td>1.690104</td>
#       <td>0.466000</td>
#       <td>0.902000</td>
#       <td>00:16</td>
#     </tr>
# ...
