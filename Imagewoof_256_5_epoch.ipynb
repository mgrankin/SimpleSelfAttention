# %% [markdown]
# ## Baseline: Adam + OneCycle

# %%
# %run train.py --run 20 --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 3 \
                --opt adam
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.164146</td>
#       <td>2.559686</td>
#       <td>0.238000</td>
#       <td>0.698000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.001559</td>
#       <td>2.355081</td>
#       <td>0.274000</td>
#       <td>0.788000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.803628</td>
#       <td>1.915962</td>
#       <td>0.358000</td>
#       <td>0.844000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.584848</td>
#       <td>1.553473</td>
#       <td>0.554000</td>
#       <td>0.940000</td>
#       <td>00:40</td>
#     </tr>
# ...

# %% [markdown]
# ## Over9000 (RAdam + LARS + LookAHead) + flat_and_anneal

# %%
# %run train.py --run 20 --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 3 \
                --opt over9000 --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.239279</td>
#       <td>2.099346</td>
#       <td>0.302000</td>
#       <td>0.764000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.018482</td>
#       <td>2.042157</td>
#       <td>0.282000</td>
#       <td>0.782000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.811257</td>
#       <td>1.722818</td>
#       <td>0.442000</td>
#       <td>0.870000</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.597335</td>
#       <td>1.475863</td>
#       <td>0.574000</td>
#       <td>0.942000</td>
#       <td>00:44</td>
#     </tr>
# ...

# %% [markdown]
# ## Ralamb (RAdam + LARS)

# %%
# %run train.py --run 20 --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 3 \
                --opt ralamb --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.282623</td>
#       <td>2.683475</td>
#       <td>0.218000</td>
#       <td>0.724000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.041888</td>
#       <td>2.405581</td>
#       <td>0.270000</td>
#       <td>0.738000</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.850386</td>
#       <td>2.035783</td>
#       <td>0.258000</td>
#       <td>0.788000</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.695415</td>
#       <td>1.661322</td>
#       <td>0.498000</td>
#       <td>0.908000</td>
#       <td>00:40</td>
#     </tr>
# ...

# %% [markdown]
# ## Ranger (RAdam + LookAHead)

# %%
# %run train.py --run 20 --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 3 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.5

# %% [markdown]
# ## Novograd + bigger lr

# %%
# %run train.py --run 20 --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 3e-2 --gpu 3 \
                --opt novograd --sched_type flat_and_anneal --ann_start 0.5

# %% [markdown]
# ## Radam

# %%
# %run train.py --run 20 --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 3 \
                --opt radam --sched_type flat_and_anneal --ann_start 0.5
