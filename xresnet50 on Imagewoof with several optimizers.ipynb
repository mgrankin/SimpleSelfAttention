# %% [markdown]
# ## Adam

# %%
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 3e-3 --gpu 3 --opt adam
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.125978</td>
#       <td>2.279570</td>
#       <td>0.220000</td>
#       <td>0.700000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.022130</td>
#       <td>3.106848</td>
#       <td>0.220000</td>
#       <td>0.736000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.865086</td>
#       <td>2.205060</td>
#       <td>0.310000</td>
#       <td>0.832000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.704577</td>
#       <td>1.794637</td>
#       <td>0.402000</td>
#       <td>0.892000</td>
#       <td>00:39</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 3e-3 --gpu 3 --opt adam
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.104153</td>
#       <td>2.311707</td>
#       <td>0.230000</td>
#       <td>0.722000</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.987256</td>
#       <td>2.212728</td>
#       <td>0.290000</td>
#       <td>0.780000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.812601</td>
#       <td>2.330759</td>
#       <td>0.356000</td>
#       <td>0.822000</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.654892</td>
#       <td>1.943088</td>
#       <td>0.434000</td>
#       <td>0.832000</td>
#       <td>00:45</td>
#     </tr>
# ...

# %%
# lr
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 1e-2 --gpu 3 --opt adam
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.165366</td>
#       <td>2.386449</td>
#       <td>0.244000</td>
#       <td>0.742000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.085010</td>
#       <td>5.465926</td>
#       <td>0.148000</td>
#       <td>0.600000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.913464</td>
#       <td>2.157691</td>
#       <td>0.308000</td>
#       <td>0.794000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.771151</td>
#       <td>1.924563</td>
#       <td>0.352000</td>
#       <td>0.874000</td>
#       <td>00:39</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 1e-2 --gpu 3 --opt adam
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.172238</td>
#       <td>2.200133</td>
#       <td>0.264000</td>
#       <td>0.736000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.051558</td>
#       <td>2.383650</td>
#       <td>0.208000</td>
#       <td>0.790000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.900136</td>
#       <td>2.702711</td>
#       <td>0.200000</td>
#       <td>0.708000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.759097</td>
#       <td>1.960588</td>
#       <td>0.336000</td>
#       <td>0.832000</td>
#       <td>00:43</td>
#     </tr>
# ...

# %% [markdown]
# ## RAdam

# %%
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 3e-3 --gpu 3 --opt radam
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.120470</td>
#       <td>2.113072</td>
#       <td>0.292000</td>
#       <td>0.774000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.035675</td>
#       <td>2.486807</td>
#       <td>0.266000</td>
#       <td>0.756000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.879226</td>
#       <td>2.102118</td>
#       <td>0.348000</td>
#       <td>0.836000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.735611</td>
#       <td>1.766654</td>
#       <td>0.450000</td>
#       <td>0.900000</td>
#       <td>00:37</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 3e-3 --gpu 3 --opt radam
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.130007</td>
#       <td>2.216874</td>
#       <td>0.250000</td>
#       <td>0.720000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.031762</td>
#       <td>2.326760</td>
#       <td>0.250000</td>
#       <td>0.734000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.846451</td>
#       <td>1.899223</td>
#       <td>0.362000</td>
#       <td>0.852000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.701442</td>
#       <td>3.635882</td>
#       <td>0.216000</td>
#       <td>0.702000</td>
#       <td>00:43</td>
#     </tr>
# ...

# %%
# lr
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 1e-2 --gpu 3 --opt radam
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.165913</td>
#       <td>2.664716</td>
#       <td>0.208000</td>
#       <td>0.676000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.041376</td>
#       <td>2.573142</td>
#       <td>0.268000</td>
#       <td>0.742000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.927589</td>
#       <td>2.546491</td>
#       <td>0.252000</td>
#       <td>0.768000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.790330</td>
#       <td>3.074256</td>
#       <td>0.310000</td>
#       <td>0.800000</td>
#       <td>00:41</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 1e-2 --gpu 3 --opt radam
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.168814</td>
#       <td>2.555089</td>
#       <td>0.212000</td>
#       <td>0.660000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.089336</td>
#       <td>5.281785</td>
#       <td>0.220000</td>
#       <td>0.692000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.974935</td>
#       <td>4.071811</td>
#       <td>0.180000</td>
#       <td>0.710000</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.775476</td>
#       <td>2.265056</td>
#       <td>0.246000</td>
#       <td>0.784000</td>
#       <td>00:43</td>
#     </tr>
# ...

# %% [markdown]
# ## Novograd

# %%
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 3e-2 --gpu 3 --opt novograd \
                --alpha 0 --mom 0.95
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.133184</td>
#       <td>2.245047</td>
#       <td>0.204000</td>
#       <td>0.720000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.021568</td>
#       <td>2.626029</td>
#       <td>0.218000</td>
#       <td>0.756000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.834925</td>
#       <td>2.032073</td>
#       <td>0.348000</td>
#       <td>0.868000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.661357</td>
#       <td>1.863610</td>
#       <td>0.394000</td>
#       <td>0.916000</td>
#       <td>00:43</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 3e-2 --gpu 3 --opt novograd \
                --alpha 0 --mom 0.95
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.135755</td>
#       <td>2.388149</td>
#       <td>0.182000</td>
#       <td>0.628000</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.042802</td>
#       <td>6.364885</td>
#       <td>0.150000</td>
#       <td>0.592000</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.885741</td>
#       <td>2.370793</td>
#       <td>0.246000</td>
#       <td>0.702000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.705030</td>
#       <td>1.876760</td>
#       <td>0.384000</td>
#       <td>0.876000</td>
#       <td>00:47</td>
#     </tr>
# ...

# %% [markdown]
# ## Ranger (RAdam + LookAHead)

# %%
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 3e-3 --gpu 3 --opt ranger
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.106912</td>
#       <td>2.146560</td>
#       <td>0.274000</td>
#       <td>0.730000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.073771</td>
#       <td>2.612315</td>
#       <td>0.244000</td>
#       <td>0.756000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.936298</td>
#       <td>2.248033</td>
#       <td>0.324000</td>
#       <td>0.778000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.792787</td>
#       <td>2.081891</td>
#       <td>0.380000</td>
#       <td>0.842000</td>
#       <td>00:41</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 3e-3 --gpu 3 --opt ranger
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.116893</td>
#       <td>2.153435</td>
#       <td>0.268000</td>
#       <td>0.724000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.066843</td>
#       <td>2.183123</td>
#       <td>0.252000</td>
#       <td>0.762000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.927670</td>
#       <td>2.431979</td>
#       <td>0.288000</td>
#       <td>0.762000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.730435</td>
#       <td>2.742985</td>
#       <td>0.298000</td>
#       <td>0.840000</td>
#       <td>00:46</td>
#     </tr>
# ...

# %%
# lr
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 1e-2 --gpu 3 --opt ranger
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.106281</td>
#       <td>2.175390</td>
#       <td>0.286000</td>
#       <td>0.772000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.023127</td>
#       <td>2.676530</td>
#       <td>0.268000</td>
#       <td>0.732000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.895995</td>
#       <td>1.972686</td>
#       <td>0.332000</td>
#       <td>0.848000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.770659</td>
#       <td>2.351446</td>
#       <td>0.308000</td>
#       <td>0.826000</td>
#       <td>00:41</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 1e-2 --gpu 3 --opt ranger
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.131116</td>
#       <td>2.166570</td>
#       <td>0.276000</td>
#       <td>0.750000</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.059313</td>
#       <td>2.906196</td>
#       <td>0.216000</td>
#       <td>0.754000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.900824</td>
#       <td>1.894327</td>
#       <td>0.362000</td>
#       <td>0.854000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.738893</td>
#       <td>1.923809</td>
#       <td>0.380000</td>
#       <td>0.862000</td>
#       <td>00:42</td>
#     </tr>
# ...

# %%
# lr
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 3e-2 --gpu 3 --opt ranger
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.183566</td>
#       <td>3.742276</td>
#       <td>0.172000</td>
#       <td>0.680000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.050870</td>
#       <td>4.894631</td>
#       <td>0.158000</td>
#       <td>0.658000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.925047</td>
#       <td>2.162105</td>
#       <td>0.202000</td>
#       <td>0.702000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.804515</td>
#       <td>2.540794</td>
#       <td>0.326000</td>
#       <td>0.816000</td>
#       <td>00:39</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 3e-2 --gpu 3 --opt ranger
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.169735</td>
#       <td>2.288863</td>
#       <td>0.242000</td>
#       <td>0.738000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.083873</td>
#       <td>3.353932</td>
#       <td>0.218000</td>
#       <td>0.700000</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.948082</td>
#       <td>2.068961</td>
#       <td>0.316000</td>
#       <td>0.786000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.790065</td>
#       <td>1.876746</td>
#       <td>0.408000</td>
#       <td>0.868000</td>
#       <td>00:44</td>
#     </tr>
# ...

# %% [markdown]
# ## Ralamb (RAdam + LARS)

# %%
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 3e-3 --gpu 3 --opt ralamb
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.122847</td>
#       <td>2.145329</td>
#       <td>0.258000</td>
#       <td>0.746000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.033736</td>
#       <td>2.215963</td>
#       <td>0.280000</td>
#       <td>0.734000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.934425</td>
#       <td>2.020458</td>
#       <td>0.366000</td>
#       <td>0.854000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.722612</td>
#       <td>1.850063</td>
#       <td>0.416000</td>
#       <td>0.858000</td>
#       <td>00:45</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 3e-3 --gpu 3 --opt ralamb
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.130956</td>
#       <td>2.121991</td>
#       <td>0.270000</td>
#       <td>0.746000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.075366</td>
#       <td>2.135875</td>
#       <td>0.284000</td>
#       <td>0.770000</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.911375</td>
#       <td>2.682869</td>
#       <td>0.268000</td>
#       <td>0.764000</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.713368</td>
#       <td>1.661864</td>
#       <td>0.488000</td>
#       <td>0.920000</td>
#       <td>00:51</td>
#     </tr>
# ...

# %%
# lr
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 1e-2 --gpu 3 --opt ralamb
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.139385</td>
#       <td>2.516358</td>
#       <td>0.168000</td>
#       <td>0.678000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.135977</td>
#       <td>2.718069</td>
#       <td>0.194000</td>
#       <td>0.664000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.949273</td>
#       <td>3.090433</td>
#       <td>0.206000</td>
#       <td>0.766000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.775962</td>
#       <td>2.009121</td>
#       <td>0.374000</td>
#       <td>0.870000</td>
#       <td>00:41</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 1e-2 --gpu 3 --opt ralamb
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.159304</td>
#       <td>2.299109</td>
#       <td>0.220000</td>
#       <td>0.692000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.126887</td>
#       <td>3.035274</td>
#       <td>0.196000</td>
#       <td>0.674000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.888912</td>
#       <td>2.014321</td>
#       <td>0.310000</td>
#       <td>0.770000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.676181</td>
#       <td>1.700454</td>
#       <td>0.438000</td>
#       <td>0.914000</td>
#       <td>00:45</td>
#     </tr>
# ...

# %%
# lr
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 3e-2 --gpu 3 --opt ralamb
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.248268</td>
#       <td>2.422140</td>
#       <td>0.210000</td>
#       <td>0.708000</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.086575</td>
#       <td>2.067492</td>
#       <td>0.332000</td>
#       <td>0.788000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.904926</td>
#       <td>2.588513</td>
#       <td>0.254000</td>
#       <td>0.740000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.767097</td>
#       <td>1.886919</td>
#       <td>0.408000</td>
#       <td>0.870000</td>
#       <td>00:47</td>
#     </tr>
# ...

# %%
# lr
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 3e-2 --gpu 3 --opt ralamb
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.239874</td>
#       <td>5.354596</td>
#       <td>0.138000</td>
#       <td>0.586000</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.100000</td>
#       <td>0.000000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.100000</td>
#       <td>0.000000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.100000</td>
#       <td>0.000000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %% [markdown]
# ## Over9000 (RAdam + LARS + LookAHead)

# %%
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 3e-3 --gpu 3 --opt over9000
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.158535</td>
#       <td>2.128317</td>
#       <td>0.270000</td>
#       <td>0.734000</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.050640</td>
#       <td>2.208627</td>
#       <td>0.258000</td>
#       <td>0.746000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.941175</td>
#       <td>2.258701</td>
#       <td>0.292000</td>
#       <td>0.768000</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.798322</td>
#       <td>2.012139</td>
#       <td>0.358000</td>
#       <td>0.794000</td>
#       <td>00:48</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 3e-3 --gpu 3 --opt over9000
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.154395</td>
#       <td>2.125631</td>
#       <td>0.236000</td>
#       <td>0.770000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.038335</td>
#       <td>2.325651</td>
#       <td>0.234000</td>
#       <td>0.766000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.887440</td>
#       <td>1.942981</td>
#       <td>0.322000</td>
#       <td>0.862000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.728713</td>
#       <td>1.970711</td>
#       <td>0.340000</td>
#       <td>0.856000</td>
#       <td>00:52</td>
#     </tr>
# ...

# %%
# lr
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 1e-2 --gpu 3 --opt over9000
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.111399</td>
#       <td>2.123973</td>
#       <td>0.278000</td>
#       <td>0.774000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.082003</td>
#       <td>2.293890</td>
#       <td>0.252000</td>
#       <td>0.728000</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.957635</td>
#       <td>2.607652</td>
#       <td>0.248000</td>
#       <td>0.736000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.744209</td>
#       <td>2.315232</td>
#       <td>0.330000</td>
#       <td>0.862000</td>
#       <td>00:47</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 1e-2 --gpu 3 --opt over9000
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.118273</td>
#       <td>2.099787</td>
#       <td>0.272000</td>
#       <td>0.758000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.182405</td>
#       <td>2.723272</td>
#       <td>0.184000</td>
#       <td>0.632000</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.021138</td>
#       <td>2.383327</td>
#       <td>0.342000</td>
#       <td>0.856000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.823339</td>
#       <td>1.836635</td>
#       <td>0.402000</td>
#       <td>0.860000</td>
#       <td>00:52</td>
#     </tr>
# ...

# %%
# lr
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 10 --lr 3e-2 --gpu 3 --opt over9000
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.158797</td>
#       <td>2.348731</td>
#       <td>0.246000</td>
#       <td>0.712000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.111881</td>
#       <td>3.444368</td>
#       <td>0.178000</td>
#       <td>0.644000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.902761</td>
#       <td>2.654396</td>
#       <td>0.258000</td>
#       <td>0.782000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.760457</td>
#       <td>2.486139</td>
#       <td>0.246000</td>
#       <td>0.762000</td>
#       <td>00:49</td>
#     </tr>
# ...

# %%
# sa
# %run train.py --woof 1 --size 256 --bs 128 --mixup 0 --sa 1 --epoch 10 --lr 3e-2 --gpu 3 --opt over9000
# Out:
# /home/u/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.165861</td>
#       <td>2.392379</td>
#       <td>0.228000</td>
#       <td>0.698000</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.079245</td>
#       <td>2.534354</td>
#       <td>0.224000</td>
#       <td>0.752000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.903700</td>
#       <td>2.440267</td>
#       <td>0.258000</td>
#       <td>0.786000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.742662</td>
#       <td>1.894593</td>
#       <td>0.400000</td>
#       <td>0.838000</td>
#       <td>00:48</td>
#     </tr>
# ...
