# %% [markdown]
# ## Baseline: Adam + OneCycle

# %%
# %run train.py --run 20 --woof 0 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 0 \
                --opt adam
# Out:
# lr: 0.003; eff_lr: 0.003; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.670087</td>
#       <td>2.096768</td>
#       <td>0.464000</td>
#       <td>0.818000</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.475968</td>
#       <td>1.685449</td>
#       <td>0.570000</td>
#       <td>0.934000</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.263887</td>
#       <td>1.382563</td>
#       <td>0.644000</td>
#       <td>0.970000</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.120718</td>
#       <td>0.988316</td>
# ...

# %% [markdown]
# ## Over9000 (RAdam + LARS + LookAHead) + flat_and_anneal

# %%
# %run train.py --run 20 --woof 0 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt over9000 --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.677033</td>
#       <td>1.619673</td>
#       <td>0.534000</td>
#       <td>0.916000</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.431901</td>
#       <td>2.172719</td>
#       <td>0.464000</td>
#       <td>0.950000</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.298357</td>
#       <td>1.041005</td>
#       <td>0.792000</td>
#       <td>0.976000</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.112046</td>
#       <td>1.007515</td>
# ...

# %% [markdown]
# ## Ralamb (RAdam + LARS)

# %%
# %run train.py --run 20 --woof 0 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt ralamb --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.765740</td>
#       <td>2.515505</td>
#       <td>0.434000</td>
#       <td>0.866000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.459736</td>
#       <td>1.649678</td>
#       <td>0.522000</td>
#       <td>0.876000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.277284</td>
#       <td>1.383323</td>
#       <td>0.630000</td>
#       <td>0.946000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.133520</td>
#       <td>0.993980</td>
# ...

# %% [markdown]
# ## Ranger

# %%
# %run train.py --run 20 --woof 0 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.716071</td>
#       <td>3.171658</td>
#       <td>0.324000</td>
#       <td>0.744000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.458289</td>
#       <td>1.852853</td>
#       <td>0.542000</td>
#       <td>0.896000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.315482</td>
#       <td>1.075275</td>
#       <td>0.786000</td>
#       <td>0.976000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.130746</td>
#       <td>1.129398</td>
# ...

# %% [markdown]
# ## Novograd + bigger lr

# %%
# %run train.py --run 20 --woof 0 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 3e-2 --gpu 0 \
                --opt novograd --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.03; eff_lr: 0.03; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.581330</td>
#       <td>1.680237</td>
#       <td>0.546000</td>
#       <td>0.914000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.348020</td>
#       <td>1.589378</td>
#       <td>0.600000</td>
#       <td>0.902000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.246612</td>
#       <td>1.584201</td>
#       <td>0.590000</td>
#       <td>0.912000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.104351</td>
#       <td>1.063320</td>
# ...

# %% [markdown]
# ## Radam

# %%
# %run train.py --run 20 --woof 0 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt radam --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.743928</td>
#       <td>2.028613</td>
#       <td>0.456000</td>
#       <td>0.894000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.522789</td>
#       <td>2.354821</td>
#       <td>0.440000</td>
#       <td>0.852000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.335666</td>
#       <td>1.436682</td>
#       <td>0.590000</td>
#       <td>0.962000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.180029</td>
#       <td>1.248156</td>
# ...
