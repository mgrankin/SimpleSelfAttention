# %% [markdown]
# ## Baseline: Adam + OneCycle

# %%
# %run train.py --run 20 --woof 0 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 1 \
                --opt adam
# Out:
# /home/u/.fastai/data/imagenette
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.663864</td>
#       <td>1.737741</td>
#       <td>0.556000</td>
#       <td>0.878000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.472986</td>
#       <td>1.555850</td>
#       <td>0.564000</td>
#       <td>0.932000</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.289799</td>
#       <td>1.131833</td>
#       <td>0.750000</td>
#       <td>0.970000</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.118519</td>
#       <td>1.001674</td>
#       <td>0.824000</td>
#       <td>0.976000</td>
#       <td>00:43</td>
#     </tr>
# ...

# %% [markdown]
# ## Over9000 (RAdam + LARS + LookAHead) + flat_and_anneal

# %%
# %run train.py --run 20 --woof 0 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 1 \
                --opt over9000 --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagenette
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.704583</td>
#       <td>3.019390</td>
#       <td>0.276000</td>
#       <td>0.812000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.463850</td>
#       <td>1.293196</td>
#       <td>0.700000</td>
#       <td>0.950000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.290636</td>
#       <td>1.108283</td>
#       <td>0.770000</td>
#       <td>0.978000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.104793</td>
#       <td>0.940994</td>
#       <td>0.830000</td>
#       <td>0.984000</td>
#       <td>00:46</td>
#     </tr>
# ...

# %% [markdown]
# ## Ralamb (RAdam + LARS)

# %%
# %run train.py --run 20 --woof 0 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 1 \
                --opt ralamb --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagenette
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.756833</td>
#       <td>1.720921</td>
#       <td>0.494000</td>
#       <td>0.926000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.457517</td>
#       <td>1.561631</td>
#       <td>0.560000</td>
#       <td>0.940000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.290753</td>
#       <td>1.293361</td>
#       <td>0.698000</td>
#       <td>0.950000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.133981</td>
#       <td>0.987360</td>
#       <td>0.832000</td>
#       <td>0.974000</td>
#       <td>00:42</td>
#     </tr>
# ...

# %% [markdown]
# ## Ranger

# %%
# %run train.py --run 20 --woof 0 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 1 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.5

# %% [markdown]
# ## Novograd + bigger lr

# %%
# %run train.py --run 20 --woof 0 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 3e-2 --gpu 1 \
                --opt novograd --sched_type flat_and_anneal --ann_start 0.5

# %% [markdown]
# ## Radam

# %%
# %run train.py --run 20 --woof 0 --size 256 --bs 128 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 1 \
                --opt radam --sched_type flat_and_anneal --ann_start 0.5
